# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image = cv2.imread('abc.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image)
plt.show()

# %%
70:120
# Out:
#   Cell In[3], line 1
#     70:120
#     ^
# SyntaxError: illegal target for annotation

# %%
470:520

# %%
32*32*3
# Out:
# 3072

# %%
template = image[675:725, 70:120].copy()
#template = image[675:725, 470:520].copy()
plt.figure(figsize=(1, 1))
plt.imshow(template)
plt.show()

# %%
match = cv2.matchTemplate(image, template, cv2.TM_CCORR_NORMED)
plt.imshow(match)
plt.colorbar()
plt.show()

# %%
np.where(match == match.max())
# Out:
# (array([675]), array([70]))

# %% [markdown]
# ____________________________________________________________

# %%
template = cv2.flip(template, 1)

# %%
image2 = cv2.imread('A_B_C.jpg')
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2RGB)
plt.imshow(image2)
plt.show()

# %%
match2 = cv2.matchTemplate(image2, template, cv2.TM_CCORR_NORMED)
plt.imshow(match2)
plt.colorbar()
plt.show()

# %%
np.where(match2 == match2.max())
# Out:
# (array([555]), array([296]))

# %%
plt.imshow(image2[555:605, 296:346])
plt.figure(figsize=(1, 1))
plt.show()
